# %%
import h5py
import os
print(os.getcwd())
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from matplotlib import gridspec
from scipy import integrate
import re,csv
# Out:
# /Users/lucym/Documents/2025/COSMIC-output

# %%
from xdata import Database

km = 10**5
Rsol = 695700

# %%
db = Database('K0559Phal250710_jwst0.hdf5')
model = db.list_items()[0]
subgroups = db.list_items(model)
print(f"subgroups: {subgroups}")
db.scan(os.path.join(model,'intrinsic'))
# Out:
# subgroups: ['intrinsic', 'o2', 'o3']
# {'name': 'a_orb_evol', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'bin_num', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('int64'), 'compression': 'gzip', 'fields': None}
# {'name': 'binary_id', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('int64'), 'compression': 'gzip', 'fields': None}
# {'name': 'chirp_mass', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'chirp_mass_det', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'chirp_time', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'delay_time', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'e_orb_evol', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'epoch_id', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('int64'), 'compression': 'gzip', 'fields': None}
# {'name': 'evolve_time', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'galaxy_id', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('int64'), 'compression': 'gzip', 'fields': None}
# {'name': 'has_BH', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('bool'), 'compression': 'gzip', 'fields': None}
# {'name': 'has_NS', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('bool'), 'compression': 'gzip', 'fields': None}
# {'name': 'is_BBH', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('bool'), 'compression': 'gzip', 'fields': None}
# {'name': 'is_BNS', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('bool'), 'compression': 'gzip', 'fields': None}
# {'name': 'is_NSBH', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('bool'), 'compression': 'gzip', 'fields': None}
# {'name': 'kstar_1', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('int64'), 'compression': 'gzip', 'fields': None}
# {'name': 'kstar_2', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('int64'), 'compression': 'gzip', 'fields': None}
# {'name': 'log_total_mass', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'lum_dist_formation', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'lum_dist_obs', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_1', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_1_det', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_2', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_2_det', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_co_1', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_co_2', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_greater', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_greater_det', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_lesser', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_lesser_det', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_ratio', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_zams_1', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'mass_zams_2', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'merge_time', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'met_zams', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'redshift_formation', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'redshift_obs', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'subgroup_id', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('int64'), 'compression': 'gzip', 'fields': None}
# {'name': 't_compact', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 't_formation', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 't_merge', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 't_obs', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'total_mass', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'total_mass_det', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'weight_intrinsic', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'weight_per_vt', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'will_merge', 'kind': 'dset', 'attrs': [], 'shape': (11711291,), 'dtype': dtype('bool'), 'compression': 'gzip', 'fields': None}
# {'name': 'zbirth', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}
# {'name': 'zmer', 'kind': 'dset', 'attrs': ['unit'], 'shape': (11711291,), 'dtype': dtype('<f8'), 'compression': 'gzip', 'fields': None}

# %%
db.scan('K0559Phal250710-jwst0')
# Out:
# {'name': 'intrinsic', 'kind': 'group', 'attrs': ['binary_fraction', 'bit_generator', 'circularize', 'formation_method', 'max_subgroup_samples', 'mergers_only', 'nsystems', 'numpy_version', 'popsynth_model', 'redshift_limit', 'required_fields', 'synthetic_universe', 'testing']}
# {'name': 'o2', 'kind': 'group', 'attrs': ['lnL_joint', 'lnL_rate', 'lnL_rate_BBH', 'lnL_rate_BNS', 'lnL_rate_NSBH', 'lnL_shape', 'mu_BBH', 'mu_BNS', 'mu_NSBH', 'observing_run', 'popsynth_model', 'rate_BBH', 'rate_BNS', 'rate_NSBH', 'required_fields', 'snr_resolution', 'synthetic_universe']}
# {'name': 'o3', 'kind': 'group', 'attrs': ['lnL_joint', 'lnL_rate', 'lnL_rate_BBH', 'lnL_rate_BNS', 'lnL_rate_NSBH', 'lnL_shape', 'mu_BBH', 'mu_BNS', 'mu_NSBH', 'observing_run', 'popsynth_model', 'rate_BBH', 'rate_BNS', 'rate_NSBH', 'required_fields', 'snr_resolution', 'synthetic_universe']}

# %%
db.list_items('K0559Phal250710-jwst0')
# Out:
# ['intrinsic', 'o2', 'o3']

# %%
db.list_items('K0559Phal250710-jwst0/intrinsic')
# Out:
# ['a_orb_evol',
#  'bin_num',
#  'binary_id',
#  'chirp_mass',
#  'chirp_mass_det',
#  'chirp_time',
#  'delay_time',
#  'e_orb_evol',
#  'epoch_id',
#  'evolve_time',
#  'galaxy_id',
#  'has_BH',
#  'has_NS',
#  'is_BBH',
#  'is_BNS',
#  'is_NSBH',
#  'kstar_1',
#  'kstar_2',
#  'log_total_mass',
#  'lum_dist_formation',
#  'lum_dist_obs',
#  'mass_1',
#  'mass_1_det',
#  'mass_2',
#  'mass_2_det',
#  'mass_co_1',
#  'mass_co_2',
#  'mass_greater',
#  'mass_greater_det',
#  'mass_lesser',
#  'mass_lesser_det',
#  'mass_ratio',
#  'mass_zams_1',
#  'mass_zams_2',
#  'merge_time',
#  'met_zams',
#  'redshift_formation',
#  'redshift_obs',
#  'subgroup_id',
#  't_compact',
#  't_formation',
#  't_merge',
#  't_obs',
#  'total_mass',
#  'total_mass_det',
#  'weight_intrinsic',
#  'weight_per_vt',
#  'will_merge',
#  'zbirth',
#  'zmer']

# %%
db.list_items('K0559Phal250710-jwst0/intrinsic')
model = db.list_items()[0]
group = os.path.join(model,"intrinsic")
print(group)
mass_1 = db.dset_value(os.path.join(group, "mass_1"))
print(mass_1)
mass_1_det = db.dset_value(os.path.join(group, "mass_1_det"))
mass_co_1 = db.dset_value(os.path.join(group, "mass_co_1"))
mass_2 = db.dset_value(os.path.join(group, "mass_1"))
# Out:
# K0559Phal250710-jwst0/intrinsic
# [ 1.2610841   1.242       1.2422635  ...  3.08872558  4.80002052
#  14.02145843]

# %%
is_BBH = db.dset_value(os.path.join(group, "is_BBH"))
print(is_BBH)
# Out:
# [False False False ...  True  True  True]

# %%
indices = np.where(is_BBH == 1)[0]

# %%
print(np.array(indices))
# Out:
# [   60000    60001    60002 ... 11711288 11711289 11711290]

# %%
len(indices)
# Out:
# 3241554

# %%
len(mass_1)
# Out:
# 11711291

# %%
idx = 0
i = indices[idx]

while indices[idx] < indices[3]:
    print("black hole mass is ", mass_1[indices[idx]])
    print("  mass co and mass_det are ", mass_co_1[indices[idx]],mass_1_det[indices[idx]])
    idx+=1
# Out:
# black hole mass is  33.88584260175061
#   mass co and mass_det are  25.978907019335526 168.87678848924298
# black hole mass is  21.668123111436223
#   mass co and mass_det are  16.741427966234617 148.0819732225175
# black hole mass is  18.019600799648032
#   mass co and mass_det are  13.875272311114323 98.27445338582393
