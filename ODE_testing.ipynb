# %%
# will test my ode solver here
import ODE_solver as odes
import numpy as np
import plot_utils as p

a = 1
b = 0.1
c = 1
d = 0.1


def dxdt(x, y):
    return -x*y


def dydt(x, y):
    return -x*y


sols = odes.solve_Radau(dxdt, dydt, x0=8, y0=8,
                        t0=0, tfinal=6, x_scale=1, y_scale=1, t_scale=1)
# extract solutions
t = sols[0]
x = sols[1]
y = sols[2]

p.plot2d(x, y, xlabel='X', ylabel='Y', title='Y(X)', legend=None, colour=None, xlim=(0, 6), ylim=(0, 6), axis_font=None, axis_size=None, title_font=None,
         title_size=None, legend_size=None, grid=None, grid_axis='both', grid_color=None, grid_linestyle='-', grid_linewidth=None, grid_transparency=1)

p.plot2d(t, x, xlabel='t', ylabel='X', title='X(t)', legend=None, colour=None, xlim=(0, 6), ylim=(0, 6), axis_font=None, axis_size=None, title_font=None,
         title_size=None, legend_size=None, grid=None, grid_axis='both', grid_color=None, grid_linestyle='-', grid_linewidth=None, grid_transparency=1)

p.plot2d(t, x, xlabel='t', ylabel='Y', title='Y(t)', legend=None, colour=None, xlim=(0, 6), ylim=(0, 6), axis_font=None, axis_size=None, title_font=None,
         title_size=None, legend_size=None, grid=None, grid_axis='both', grid_color=None, grid_linestyle='-', grid_linewidth=None, grid_transparency=1)
