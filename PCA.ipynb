# %%
import functions as f
f.pca(file_paths=["all_ok_scaled.csv", "freq_ok_redo_scaled.csv"], target_col='spin parameter a_spin', feature_cols=['m_WR/M_Sun', 'q', 'm_companion/M_Sun', 'k', 'Q', 'initial separation a0 (m)', 'WR star Radius R_WR', 'R_WR/a0', 'initial spin Omega0 (Hz)', 'lifetime (years)','tidal function timescale (years)','initial frequency f0 (Hz)'], n_components=5)
# Out:
# --- Feature Loadings Key ---
# m_WR/M_Sun: PC1=0.417, PC2=0.134
# q: PC1=0.422, PC2=0.031
# m_companion/M_Sun: PC1=-0.278, PC2=0.438
# k: PC1=0.000, PC2=0.000
# Q: PC1=0.000, PC2=-0.000
# initial separation a0 (m): PC1=0.216, PC2=0.506
# WR star Radius R_WR: PC1=0.425, PC2=0.120
# R_WR/a0: PC1=0.413, PC2=-0.176
# initial spin Omega0 (Hz): PC1=-0.000, PC2=-0.000
# lifetime (years): PC1=-0.022, PC2=0.417
# tidal function timescale (years): PC1=-0.143, PC2=0.545
# initial frequency f0 (Hz): PC1=-0.389, PC2=-0.134

# %%
#same but for mid
import functions as f
f.pca(file_paths="Data_mid.csv", target_col='spin parameter a_spin', feature_cols=['m_WR/M_Sun', 'q', 'm_companion/M_Sun', 'k', 'Q', 'initial separation a0 (m)', 'WR star Radius R_WR', 'R_WR/a0', 'initial spin Omega0 (Hz)', 'lifetime (years)','tidal function timescale (years)','initial frequency f0 (Hz)'], n_components=5)

# %%
import functions as f
f.pca(file_paths=["all_ok_scaled.csv", "freq_ok_redo_scaled.csv"], target_col='spin parameter a_spin', feature_cols=['m_WR/M_Sun', 'q', 'm_companion/M_Sun', 'initial separation a0 (m)', 'R_WR/a0','tidal function timescale (years)','initial frequency f0 (Hz)'], n_components=5)
# Out:
# --- Feature Loadings Key ---
# m_WR/M_Sun: PC1=0.448, PC2=0.203
# q: PC1=0.460, PC2=0.095
# m_companion/M_Sun: PC1=-0.338, PC2=0.456
# initial separation a0 (m): PC1=0.202, PC2=0.585
# R_WR/a0: PC1=0.466, PC2=-0.136
# tidal function timescale (years): PC1=-0.197, PC2=0.586
# initial frequency f0 (Hz): PC1=-0.421, PC2=-0.190

# %%
import functions as f
f.pca(file_paths=["all_ok_scaled.csv", "freq_ok_redo_scaled.csv"], target_col='spin parameter a_spin', feature_cols=['m_WR/M_Sun', 'q', 'initial separation a0 (m)', 'R_WR/a0','initial frequency f0 (Hz)'], n_components=5)
# Out:
# --- Feature Loadings Key ---
# m_WR/M_Sun: PC1=0.496, PC2=0.015
# q: PC1=0.484, PC2=-0.186
# initial separation a0 (m): PC1=0.334, PC2=0.821
# R_WR/a0: PC1=0.439, PC2=-0.532
# initial frequency f0 (Hz): PC1=-0.465, PC2=-0.091

# %%
#mid
import functions as f
f.pca(file_paths="Data_mid.csv", target_col='spin parameter a_spin', feature_cols=['m_WR/M_Sun', 'q', 'm_companion/M_Sun', 'initial separation a0 (m)', 'R_WR/a0','tidal function timescale (years)','initial frequency f0 (Hz)'], n_components=5)

# %%
import functions as f
f.pca(file_paths="Data_mid.csv", target_col='spin parameter a_spin', feature_cols=['m_WR/M_Sun', 'q', 'initial separation a0 (m)', 'R_WR/a0','initial frequency f0 (Hz)'], n_components=5)
# Out:
# --- Feature Loadings Key ---
# m_WR/M_Sun: PC1=0.534, PC2=-0.076
# q: PC1=0.372, PC2=0.582
# initial separation a0 (m): PC1=0.407, PC2=-0.535
# R_WR/a0: PC1=0.423, PC2=0.497
# initial frequency f0 (Hz): PC1=-0.482, PC2=0.350
