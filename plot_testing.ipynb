# %%
import plot_utils as p
import numpy as np

x = np.linspace(0, 1, 100)
y = x

p.plot2d(x, y, xlabel='x', ylabel='y', title='y(x)', legend=['y(x)'], colour='magenta', xlim=None, ylim=None,
         axis_font='Arial', axis_size=25, title_font="Georgia", title_size=13, legend_size=None)

# %%
import matplotlib.font_manager as fm

sorted(set(f.name for f in fm.fontManager.ttflist if "tahoma" in f.name.lower()))
# Out:
# []

# %%
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt

fp = FontProperties(fname="/usr/share/fonts/truetype/microsoft/tahoma.ttf")

plt.title("FILE PATH TEST", fontproperties=fp)
plt.show()

# %%
import numpy as np
import plot_utils as p

# ----- Create x and y -----
x = np.linspace(-3, 3, 50)
y = np.linspace(-3, 3, 40)

# ----- Create Z using meshgrid outside -----
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)      # any function works

# ----- Call your contour function -----
p.plot2d_contour(x, y, Z, contour=True, levels=30, cmap='viridis', xlabel="x-axis", ylabel="y-axis", title="Test Contour Plot"
                 )
